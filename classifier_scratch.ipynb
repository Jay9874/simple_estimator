# %% [markdown]
# In this tutorial, I am going to write a classifier model from scratch.

# %% [markdown]
# 1. First step to prepare the training data
# and loading it.

# %%
import pandas as pd
dataset = pd.read_csv('dataset.csv')
dataset
# Out:
#     Color  Diam  Label
# 0   Green     3  Apple
# 1  Yellow     3  Apple
# 2     Red     1  Grape
# 3     Red     1  Grape
# 4  Yellow     3  Lemon
